# %%
# !pip uninstall ipython -y
# Out:
# Found existing installation: ipython 9.4.0
# Uninstalling ipython-9.4.0:
#   Successfully uninstalled ipython-9.4.0

# %%
# !pip install ipython==8.24.0
# Out:
# Collecting ipython==8.24.0
#   Downloading ipython-8.24.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: decorator in /Users/moe/miniconda3/lib/python3.13/site-packages (from ipython==8.24.0) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/moe/miniconda3/lib/python3.13/site-packages (from ipython==8.24.0) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/moe/miniconda3/lib/python3.13/site-packages (from ipython==8.24.0) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/moe/miniconda3/lib/python3.13/site-packages (from ipython==8.24.0) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /Users/moe/miniconda3/lib/python3.13/site-packages (from ipython==8.24.0) (2.19.1)
# Requirement already satisfied: stack-data in /Users/moe/miniconda3/lib/python3.13/site-packages (from ipython==8.24.0) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/moe/miniconda3/lib/python3.13/site-packages (from ipython==8.24.0) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /Users/moe/miniconda3/lib/python3.13/site-packages (from ipython==8.24.0) (4.9.0)
# Requirement already satisfied: wcwidth in /Users/moe/miniconda3/lib/python3.13/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython==8.24.0) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/moe/miniconda3/lib/python3.13/site-packages (from jedi>=0.16->ipython==8.24.0) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/moe/miniconda3/lib/python3.13/site-packages (from pexpect>4.3->ipython==8.24.0) (0.7.0)
# Requirement already satisfied: executing in /Users/moe/miniconda3/lib/python3.13/site-packages (from stack-data->ipython==8.24.0) (0.8.3)
# Requirement already satisfied: asttokens in /Users/moe/miniconda3/lib/python3.13/site-packages (from stack-data->ipython==8.24.0) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/moe/miniconda3/lib/python3.13/site-packages (from stack-data->ipython==8.24.0) (0.2.2)
# Downloading ipython-8.24.0-py3-none-any.whl (816 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 816.5/816.5 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: ipython
# Successfully installed ipython-8.24.0

# %%
from spacy import displacy

# %%
import spacy
from spacy import displacy
from spacy import tokenizer

# %%
nlp = spacy.load("en_core_web_sm")

# %%
google_text = """The discography of American heavy metal band Metallica includes 11 studio albums, one covers album, eight live albums, three extended plays, 49 singles, 10 video albums, 43 music videos, one soundtrack album, one collaboration album and three box sets. They are a San Francisco-based metal band formed in 1981 by James Hetfield (lead vocals, rhythm guitar) and Lars Ulrich (drums). After several bassist and lead guitarist changes (including Dave Mustaine), the band settled on Cliff Burton and Kirk Hammett, respectively. Metallica started playing locally, releasing their first widely circulated demo, No Life 'til Leather, in 1982. The demo caught the attention of Johny Zazula, who signed Metallica to Megaforce Records.[1]

The band released Kill 'Em All in 1983, and the following year they released Ride the Lightning. After Ride the Lightning was released, Metallica left Megaforce and signed to Elektra Records.[2] In March 1986, the band released its third studio album, Master of Puppets, which was Metallica's first album to be certified gold by the Recording Industry Association of America (RIAA).[3] While promoting the album, Burton was killed in a bus accident;[4] Jason Newsted was hired as a replacement.[5] The band's first release to feature Newsted was The $5.98 E.P. – Garage Days Re-Revisited EP, and then followed by ...And Justice for All in August 1988, which peaked at number six on the Billboard 200.[6]

Metallica's fifth, self-titled album, often called The Black Album, was released in 1991 and debuted at number one on the Billboard 200.[6] The band embarked on a two-year tour in support of the album. Metallica has since been certified 2× Diamond by the RIAA.[3] Metallica followed with the release of Load and Reload in 1996 and 1997, respectively.[7] Both albums debuted at number one on the Billboard 200.[6] After the release of Garage Inc. (1998) and S&M (1999), Newsted (who would later join Voivod) left the band.[8] Metallica recorded St. Anger without an official bassist (bass parts for the writing & recording during the album sessions were played by the band's long-time producer Bob Rock). Bassist Robert Trujillo joined Metallica in 2003.[9] In 2008, the band released their ninth studio album, Death Magnetic, which was produced by Rick Rubin and distributed through Warner Bros. Records.[10][11] In April 2009, the band's catalogue was released on the iTunes Store as the Metallica Collection.[12] A collaborative album with Lou Reed, Lulu, was released in 2011.[13]

In 2013, Metallica released the movie Metallica: Through the Never, together with its soundtrack. Metallica then started writing their tenth studio album, Hardwired... to Self-Destruct, which was released in 2016. It became the band's sixth album to debut at number one on the Billboard 200 and topped the charts in 57 countries.[14][15] Metallica released their eleventh studio album, 72 Seasons, in 2023. It debuted at number two on the Billboard 200, becoming their first album since ...And Justice for All not to debut at number one.[16] Nevertheless, it was their first to debut at number one in the UK since Death Magnetic.[17] Metallica has sold more than 150 million albums worldwide,[18] with over 67 million records in the United States alone (56.3 million albums since 1991 when SoundScan started tracking actual sales figures)."""

# %%
spacy_doc = nlp(google_text)

# %%
for word in spacy_doc.ents:
    print(word.text, word.label_)
# Out:
# American NORP
# Metallica PERSON
# 11 CARDINAL
# one CARDINAL
# eight CARDINAL
# three CARDINAL
# 49 CARDINAL
# 10 CARDINAL
# 43 CARDINAL
# one CARDINAL
# three CARDINAL
# San Francisco GPE
# 1981 DATE
# James Hetfield PERSON
# Lars Ulrich PERSON
# Dave Mustaine PERSON
# Cliff Burton PERSON
# Kirk Hammett PERSON
# Metallica PERSON
# first ORDINAL
# No Life ' WORK_OF_ART
# 1982 DATE
# Johny Zazula PERSON
# Metallica PERSON
# Kill PERSON
# 1983 DATE
# the following year DATE
# Ride the Lightning WORK_OF_ART
# Metallica PERSON
# Megaforce GPE
# Elektra PRODUCT
# March 1986 DATE
# third ORDINAL
# Metallica PERSON
# first ORDINAL
# the Recording Industry Association of America ORG
# Burton PERSON
# Jason Newsted PERSON
# first ORDINAL
# Newsted was The WORK_OF_ART
# 5.98 MONEY
# August 1988 DATE
# six CARDINAL
# Metallica PERSON
# fifth ORDINAL
# The Black Album WORK_OF_ART
# 1991 DATE
# number one CARDINAL
# two-year DATE
# Metallica PERSON
# 2× Diamond PERSON
# the RIAA.[3] Metallica ORG
# Load and Reload WORK_OF_ART
# 1996 DATE
# 1997 DATE
# number one CARDINAL
# Garage Inc. ORG
# 1998 DATE
# S&M PERSON
# 1999 DATE
# Voivod PERSON
# Metallica GPE
# St. Anger GPE
# Bob Rock PERSON
# Robert Trujillo PERSON
# Metallica PERSON
# 2003.[9 CARDINAL
# 2008 DATE
# ninth ORDINAL
# Death Magnetic ORG
# Rick Rubin PERSON
# Warner Bros. ORG
# April 2009 DATE
# the iTunes Store ORG
# Metallica PERSON
# Lou Reed PERSON
# Lulu PERSON
# 2011.[13 CARDINAL
# 2013 DATE
# Metallica PERSON
# Metallica: Through the Never WORK_OF_ART
# Metallica PERSON
# tenth ORDINAL
# 2016 DATE
# sixth ORDINAL
# number one CARDINAL
# the Billboard 200 PRODUCT
# 57 CARDINAL
# Metallica PERSON
# eleventh ORDINAL
# 72 Seasons WORK_OF_ART
# 2023 DATE
# number two CARDINAL
# the Billboard 200 PRODUCT
# first ORDINAL
# first ORDINAL
# number one CARDINAL
# UK GPE
# Death Magnetic.[17] ORG
# Metallica PERSON
# more than 150 million CARDINAL
# over 67 million CARDINAL
# the United States GPE
# 56.3 million CARDINAL
# since 1991 DATE
# SoundScan ORG

# %%
from spacy import displacy

# %%
displacy.render(spacy_doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The discography of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  heavy metal band
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Metallica
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  includes
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  studio albums,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  covers album,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eight
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  live albums,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  extended plays,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     49
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  singles,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  video albums,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     43
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  music videos,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
#
# metallicas fifth selftitled album often called the black album was released in 1991 and debuted at number one on the billboard 2006 the band embarked on a twoyear tour in support of the album metallica has since been certified 2 diamond by the riaa3 metallica followed with the release of load and reload in 1996 and 1997 respectively7 both albums debuted at number one on the billboard 2006 after the release of garage inc 1998 and sm 1999 newsted who would later join voivod left the band8 metallica recorded st anger without an official bassist bass parts for the writing  recording during the album sessions were played by the bands longtime producer bob rock bassist robert trujillo joined metallica in 20039 in 2008 the band released their ninth studio album death magnetic which was produced by rick rubin and distributed through warner bros records1011 in april 2009 the bands catalogue was released on the itunes store as the metallica collection12 a collaborative album with lou reed lulu was released in 201113
#
# in 2013 metallica released the movie metallica through the never together with its soundtrack metallica then started writing their tenth studio album hardwired to selfdestruct which was released in 2016 it became the bands sixth album to debut at number one on the billboard 200 and topped the charts in 57 countries1415 metallica released their eleventh studio album 72 seasons in 2023 it debuted at number two on the billboard 200 becoming their first album since and justice for all not to debut at number one16 nevertheless it was their first to debut at number one in the uk since death magnetic17 metallica has sold more than 150 million albums worldwide18 with over 67 million records in the united states alone 563 million albums since 1991 when soundscan started tracking actual sales figures

# %%
for word in spacy_doc_clean.ents:
    print(word.text, word.label_)
# Out:
# american NORP
# 11 CARDINAL
# one CARDINAL
# eight CARDINAL
# three CARDINAL
# 49 CARDINAL
# 10 CARDINAL
# 43 CARDINAL
# one CARDINAL
# three CARDINAL
# 1981 DATE
# james hetfield PERSON
# dave mustaine PERSON
# burton PERSON
# kirk hammett PERSON
# metallica PERSON
# first ORDINAL
# 1982 DATE
# johny zazula PERSON
# 1983 DATE
# the following year DATE
# march 1986 DATE
# third ORDINAL
# first ORDINAL
# burton PERSON
# first ORDINAL
# 598 CARDINAL
# august 1988 DATE
# number six CARDINAL
# 2006 DATE
# fifth ORDINAL
# 1991 DATE
# number one CARDINAL
# 2006 DATE
# 2 CARDINAL
# 1996 DATE
# 1997 DATE
# respectively7 ORG
# number one CARDINAL
# 2006 DATE
# 1998 DATE
# 1999 DATE
# band8 ORG
# robert trujillo PERSON
# metallica PERSON
# 20039 DATE
# 2008 DATE
# ninth ORDINAL
# rick rubin PERSON
# warner bros records1011 ORG
# april 2009 DATE
# 201113 DATE
# 2013 DATE
# tenth ORDINAL
# 2016 DATE
# sixth ORDINAL
# number one CARDINAL
# 200 CARDINAL
# 57 CARDINAL
# countries1415 GPE
# eleventh ORDINAL
# 72 seasons DATE
# 2023 DATE
# number two CARDINAL
# 200 CARDINAL
# first ORDINAL
# first ORDINAL
# number one CARDINAL
# uk GPE
# more than 150 million CARDINAL
# over 67 million CARDINAL
# the united states GPE
# 563 million CARDINAL
# 1991 DATE

# %%
displacy.render(spacy_doc_clean, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the discography of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     american
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  heavy metal band metallica includes
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  studio albums
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  covers album
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eight
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  live albums
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  extended plays
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     49
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  singles
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  video albums
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     43
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  music videos
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  soundtrack album one collaboration album and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  box sets they are a san franciscobased metal band formed in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1981
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     james hetfield
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  lead vocals rhythm guitar and lars ulrich drums after several bassist and lead guitarist changes including
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dave mustaine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  the band settled on cliff
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     burton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kirk hammett
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  respectively
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     metallica
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  started playing locally releasing their
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  widely circulated demo no life til leather in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1982
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  the demo caught the attention of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     johny zazula
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  who signed metallica to megaforce records1<br><br>the band released kill em all in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1983
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the following year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  they released ride the lightning after ride the lightning was released metallica left megaforce and signed to elektra records2 in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     march 1986
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  the band released its
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  studio album master of puppets which was metallicas
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0
