# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import spacy
import re
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Data

# %%
bbc_data = pd.read_csv("bbc_news.csv")

# %%
bbc_data.head()
# Out:
#    Unnamed: 0  index                                              title  \
# 0           0   6684                              Can I refuse to work?
# 1           1   9267  'Liz Truss the Brief?' World reacts to UK poli...
# 2           2   7387  Rationing energy is nothing new for off-grid c...
# 3           3    767  The hunt for superyachts of sanctioned Russian...
# 4           4   3712  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                          pubDate  \
# 0  Wed, 10 Aug 2022 15:46:18 GMT
# 1  Mon, 17 Oct 2022 11:35:12 GMT
# 2  Wed, 31 Aug 2022 05:20:18 GMT
# 3  Tue, 22 Mar 2022 14:37:01 GMT
# 4  Wed, 01 Jun 2022 23:17:33 GMT
#
#                                                 guid  \
# 0       https://www.bbc.co.uk/news/business-62147992
# 1          https://www.bbc.co.uk/news/world-63285480
# 2  https://www.bbc.co.uk/news/uk-scotland-highlan...
# 3                https://www.bbc.co.uk/news/60739336
# 4             https://www.bbc.co.uk/news/uk-61660128
#
#                                                 link  \
# 0  https://www.bbc.co.uk/news/business-62147992?a...
# 1  https://www.bbc.co.uk/news/world-63285480?at_m...
# 2  https://www.bbc.co.uk/news/uk-scotland-highlan...
# 3  https://www.bbc.co.uk/news/60739336?at_medium=...
# 4  https://www.bbc.co.uk/news/uk-61660128?at_medi...
#
#                                          description
# 0  With much of the UK enduring another period of...
# 1  The UK's political chaos has been watched arou...
# 2  Scoraig in the north west Highlands has long h...
# 3  Wealthy Russians sanctioned by the US, EU and ...
# 4  A quick look back at the Queen's 70 years on t...

# %%
bbc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1000 non-null   int64
#  1   index        1000 non-null   int64
#  2   title        1000 non-null   object
#  3   pubDate      1000 non-null   object
#  4   guid         1000 non-null   object
#  5   link         1000 non-null   object
#  6   description  1000 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 54.8+ KB

# %%
titles = pd.DataFrame(bbc_data['title'])

# %%
titles.head()
# Out:
#                                                title
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...

# %% [markdown]
# ## Clean Data

# %%
# lowercase
titles['lowercase'] = titles['title'].str.lower()
titles.head()
# Out:
#                                                title  \
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                                            lowercase  \
# 0                              can i refuse to work?
# 1  'liz truss the brief?' world reacts to uk poli...
# 2  rationing energy is nothing new for off-grid c...
# 3  the hunt for superyachts of sanctioned russian...
# 4  platinum jubilee: 70 years of the queen in 70 ...
#
#                                         no_stopwords  \
# 0                                       refuse work?
# 1  'liz truss brief?' world reacts uk political t...
# 2    rationing energy nothing new off-grid community
# 3      hunt superyachts sanctioned russian oligarchs
# 4        platinum jubilee: 70 years queen 70 seconds
#
#                         no_stopwords_no_punct  \
# 0                                  refusework
# 1  liztrussbriefworldreactsukpoliticalturmoil
# 2   rationingenergynothingnewoffgridcommunity
# 3   huntsuperyachtssanctionedrussianoligarchs
# 4        platinumjubilee70yearsqueen70seconds
#
#                                            token_raw  \
# 0                      [Can, I, refuse, to, work, ?]
# 1  ['Liz, Truss, the, Brief, ?, ', World, reacts,...
# 2  [Rationing, energy, is, nothing, new, for, off...
# 3  [The, hunt, for, superyachts, of, sanctioned, ...
# 4  [Platinum, Jubilee, :, 70, years, of, the, Que...
#
#                                    tokens_clean  \
# 0                                  [refusework]
# 1  [liztrussbriefworldreactsukpoliticalturmoil]
# 2   [rationingenergynothingnewoffgridcommunity]
# 3   [huntsuperyachtssanctionedrussianoligarchs]
# 4        [platinumjubilee70yearsqueen70seconds]
#
#                         tokens_clean_lemmatized
# 0                                  [refusework]
# 1  [liztrussbriefworldreactsukpoliticalturmoil]
# 2   [rationingenergynothingnewoffgridcommunity]
# 3   [huntsuperyachtssanctionedrussianoligarchs]
# 4        [platinumjubilee70yearsqueen70seconds]

# %%
# stop word removal
en_stopwords = stopwords.words('english')
titles['no_stopwords'] = titles['lowercase'].apply(lambda x: ' '.join([word for word in x.split() if word not in (en_stopwords)]))
titles.head()
# Out:
#                                                title  \
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                                            lowercase  \
# 0                              can i refuse to work?
# 1  'liz truss the brief?' world reacts to uk poli...
# 2  rationing energy is nothing new for off-grid c...
# 3  the hunt for superyachts of sanctioned russian...
# 4  platinum jubilee: 70 years of the queen in 70 ...
#
#                                         no_stopwords  \
# 0                                       refuse work?
# 1  'liz truss brief?' world reacts uk political t...
# 2    rationing energy nothing new off-grid community
# 3      hunt superyachts sanctioned russian oligarchs
# 4        platinum jubilee: 70 years queen 70 seconds
#
#                         no_stopwords_no_punct  \
# 0                                  refusework
# 1  liztrussbriefworldreactsukpoliticalturmoil
# 2   rationingenergynothingnewoffgridcommunity
# 3   huntsuperyachtssanctionedrussianoligarchs
# 4        platinumjubilee70yearsqueen70seconds
#
#                                            token_raw  \
# 0                      [Can, I, refuse, to, work, ?]
# 1  ['Liz, Truss, the, Brief, ?, ', World, reacts,...
# 2  [Rationing, energy, is, nothing, new, for, off...
# 3  [The, hunt, for, superyachts, of, sanctioned, ...
# 4  [Platinum, Jubilee, :, 70, years, of, the, Que...
#
#                                    tokens_clean  \
# 0                                  [refusework]
# 1  [liztrussbriefworldreactsukpoliticalturmoil]
# 2   [rationingenergynothingnewoffgridcommunity]
# 3   [huntsuperyachtssanctionedrussianoligarchs]
# 4        [platinumjubilee70yearsqueen70seconds]
#
#                         tokens_clean_lemmatized
# 0                                  [refusework]
# 1  [liztrussbriefworldreactsukpoliticalturmoil]
# 2   [rationingenergynothingnewoffgridcommunity]
# 3   [huntsuperyachtssanctionedrussianoligarchs]
# 4        [platinumjubilee70yearsqueen70seconds]

# %%
# punctuation removal
titles['no_stopwords_no_punct'] = titles.apply(lambda x: re.sub(r"([^\w\w])", "", x['no_stopwords']), axis=1)
titles.head()
# Out:
#                                                title  \
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                                            lowercase  \
# 0                              can i refuse to work?
# 1  'liz truss the brief?' world reacts to uk poli...
# 2  rationing energy is nothing new for off-grid c...
# 3  the hunt for superyachts of sanctioned russian...
# 4  platinum jubilee: 70 years of the queen in 70 ...
#
#                                         no_stopwords  \
# 0                                       refuse work?
# 1  'liz truss brief?' world reacts uk political t...
# 2    rationing energy nothing new off-grid community
# 3      hunt superyachts sanctioned russian oligarchs
# 4        platinum jubilee: 70 years queen 70 seconds
#
#                         no_stopwords_no_punct  \
# 0                                  refusework
# 1  liztrussbriefworldreactsukpoliticalturmoil
# 2   rationingenergynothingnewoffgridcommunity
# 3   huntsuperyachtssanctionedrussianoligarchs
# 4        platinumjubilee70yearsqueen70seconds
#
#                                            token_raw  \
# 0                      [Can, I, refuse, to, work, ?]
# 1  ['Liz, Truss, the, Brief, ?, ', World, reacts,...
# 2  [Rationing, energy, is, nothing, new, for, off...
# 3  [The, hunt, for, superyachts, of, sanctioned, ...
# 4  [Platinum, Jubilee, :, 70, years, of, the, Que...
#
#                                    tokens_clean  \
# 0                                  [refusework]
# 1  [liztrussbriefworldreactsukpoliticalturmoil]
# 2   [rationingenergynothingnewoffgridcommunity]
# 3   [huntsuperyachtssanctionedrussianoligarchs]
# 4        [platinumjubilee70yearsqueen70seconds]
#
#                         tokens_clean_lemmatized
# 0                                  [refusework]
# 1  [liztrussbriefworldreactsukpoliticalturmoil]
# 2   [rationingenergynothingnewoffgridcommunity]
# 3   [huntsuperyachtssanctionedrussianoligarchs]
# 4        [platinumjubilee70yearsqueen70seconds]

# %%
# tokenize
titles['tokens_raw'] = titles.apply(lambda x: word_tokenize(x['title']), axis=1)
titles['tokens_clean'] = titles.apply(lambda x: word_tokenize(x['no_stopwords_no_punct']), axis=1)
titles.head()
# Out:
#                                                title  \
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                                            lowercase  \
# 0                              can i refuse to work?
# 1  'liz truss the brief?' world reacts to uk poli...
# 2  rationing energy is nothing new for off-grid c...
# 3  the hunt for superyachts of sanctioned russian...
# 4  platinum jubilee: 70 years of the queen in 70 ...
#
#                                         no_stopwords  \
# 0                                       refuse work?
# 1  'liz truss brief?' world reacts uk political t...
# 2    rationing energy nothing new off-grid community
# 3      hunt superyachts sanctioned russian oligarchs
# 4        platinum jubilee: 70 years queen 70 seconds
#
#                         no_stopwords_no_punct  \
# 0                                  refusework
# 1  liztrussbriefworldreactsukpoliticalturmoil
# 2   rationingenergynothingnewoffgridcommunity
# 3   huntsuperyachtssanctionedrussianoligarchs
# 4        platinumjubilee70yearsqueen70seconds
#
#                                            token_raw  \
# 0                      [Can, I, refuse, to, work, ?]
# 1  ['Liz, Truss, the, Brief, ?, ', World, reacts,...
# 2  [Rationing, energy, is, nothing, new, for, off...
# 3  [The, hunt, for, superyachts, of, sanctioned, ...
# 4  [Platinum, Jubilee, :, 70, years, of, the, Que...
#
#                                    tokens_clean  \
# 0                                  [refusework]
# 1  [liztrussbriefworldreactsukpoliticalturmoil]
# 2   [rationingenergynothingnewoffgridcommunity]
# 3   [huntsuperyachtssanctionedrussianoligarchs]
# 4        [platinumjubilee70yearsqueen70seconds]
#
#                         tokens_clean_lemmatized  \
# 0                                  [refusework]
# 1  [liztrussbriefworldreactsukpoliticalturmoil]
# 2   [rationingenergynothingnewoffgridcommunity]
# 3   [huntsuperyachtssanctionedrussianoligarchs]
# 4        [platinumjubilee70yearsqueen70seconds]
#
#                                           tokens_raw
# 0                      [Can, I, refuse, to, work, ?]
# 1  ['Liz, Truss, the, Brief, ?, ', World, reacts,...
# 2  [Rationing, energy, is, nothing, new, for, off...
# 3  [The, hunt, for, superyachts, of, sanctioned, ...
# 4  [Platinum, Jubilee, :, 70, years, of, the, Que...

# %%
#lemmatize
lemmatizer = WordNetLemmatizer()
titles["tokens_clean_lemmatized"] = titles["tokens_clean"].apply(lambda tokens: [lemmatizer.lemmatize(token) for token in tokens]) 
titles.head()
# Out:
#                                                title  \
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                                            lowercase  \
# 0                              can i refuse to work?
# 1  'liz truss the brief?' world reacts to uk poli...
# 2  rationing energy is nothing new for off-grid c...
# 3  the hunt for superyachts of sanctioned russian...
# 4  platinum jubilee: 70 years of the queen in 70 ...
#
#                                         no_stopwords  \
# 0                                       refuse work?
# 1  'liz truss brief?' world reacts uk political t...
# 2    rationing energy nothing new off-grid community
# 3      hunt superyachts sanctioned russian oligarchs
# 4        platinum jubilee: 70 years queen 70 seconds
#
#                         no_stopwords_no_punct  \
# 0                                  refusework
# 1  liztrussbriefworldreactsukpoliticalturmoil
# 2   rationingenergynothingnewoffgridcommunity
# 3   huntsuperyachtssanctionedrussianoligarchs
# 4        platinumjubilee70yearsqueen70seconds
#
#                                            token_raw  \
# 0                      [Can, I, refuse, to, work, ?]
# 1  ['Liz, Truss, the, Brief, ?, ', World, reacts,...
# 2  [Rationing, energy, is, nothing, new, for, off...
# 3  [The, hunt, for, superyachts, of, sanctioned, ...
# 4  [Platinum, Jubilee, :, 70, years, of, the, Que...
#
#                                    tokens_clean  \
# 0                                  [refusework]
# 1  [liztrussbriefworldreactsukpoliticalturmoil]
# 2   [rationingenergynothingnewoffgridcommunity]
# 3   [huntsuperyachtssanctionedrussianoligarchs]
# 4        [platinumjubilee70yearsqueen70seconds]
#
#                         tokens_clean_lemmatized  \
# 0                                  [refusework]
# 1  [liztrussbriefworldreactsukpoliticalturmoil]
# 2   [rationingenergynothingnewoffgridcommunity]
# 3   [huntsuperyachtssanctionedrussianoligarchs]
# 4        [platinumjubilee70yearsqueen70seconds]
#
#                                           tokens_raw
# 0                      [Can, I, refuse, to, work, ?]
# 1  ['Liz, Truss, the, Brief, ?, ', World, reacts,...
# 2  [Rationing, energy, is, nothing, new, for, off...
# 3  [The, hunt, for, superyachts, of, sanctioned, ...
# 4  [Platinum, Jubilee, :, 70, years, of, the, Que...

# %%
# create lists for just our tokens
tokens_raw_list = sum(titles['tokens_raw'], []) #unpack our lists into a single list
tokens_clean_list = sum(titles['tokens_clean_lemmatized'], [])

# %% [markdown]
# ## POS Tagging

# %% [markdown]
# ### Raw

# %%
nlp = spacy.load('en_core_web_sm')

# %%
spacy_doc = nlp(' '.join(tokens_raw_list))
spacy_doc
# Out:
# Can I refuse to work ? 'Liz Truss the Brief ? ' World reacts to UK political turmoil Rationing energy is nothing new for off-grid community The hunt for superyachts of sanctioned Russian oligarchs Platinum Jubilee : 70 years of the Queen in 70 seconds Red Bull found guilty of breaking Formula 1 's budget cap World Triathlon Championship Series : Flora Duffy beats Georgia Taylor-Brown to women 's title Terry Hall : Coventry scooter ride-out pays tribute to singer Post Office and Fujitsu to face inquiry over Horizon scandal 'Pavement parking frightens me ' UK interest rates : How will the rise affect you and how high could it go ? They stayed for the storm - what happens now ? Six Nations : Can Scotland 's best since '99 beat best Ireland ever ? How long can Liz Truss survive as prime minister ? Platinum Jubilee : Beacons light across the globe to celebrate Queen 's reign Top student loan interest rate cut by 5 % in England Russians said they ’ d take my baby : A medic ’ s story Week in pictures : 11-17 June 2022 Xi Jinping in Hong Kong : Tight security as city marks 25 years of handover Rescues carried out in silence to listen for sounds of life Nick Pope : Newcastle goalkeeper extends incredible clean sheet record How China plans to become the next big space power Barcelona thrash leaders Real Madrid in famous Clasico win Kuenssberg : The Budget can not mask big changes to our economy Nicola Bulley search : What we know about her disappearance Cost of living : Can Christmas lights displays survive the energy crisis ? The 100-year-old Edinburgh man still working three days a week Freya the 600kg walrus causes a stir in Norway How can I offer a UK home to Ukrainian refugees ? Nicola Bulley search : Former police boss says criticism is unfair Don Bolduc : Democrats elevated this Republican . Will it backfire ? Some strike action cancelled after the Queen 's death The neighbourhood leading a green energy revolution Men 's U17 European Championship : Dutch 17-year-old Isaac Babadi scores Panenka penalty Amtrak derailment : Three killed in Missouri after train hits truck Energy price cap : Rising bills - four discounts and payments that could help you Environment : Are mushroom boards the future of surfing ? Flying boats and other tech for cleaner shipping Scottish football to ban heading the day before and after matches Chris Eubank Jr v Liam Smith : What next for boxing after 'unacceptable ' taunts ? The town destroyed to make way for a whites-only suburb Ukraine war : A village celebrates Russian retreat Root hits ton as England take command against West Indies Heineken Champions Cup : Leicester 16-6 Edinburgh - Jasper Wiese try sends Tigers into last eight World Cup 2022 : Bellingham , Gakpo , Fernandez and other breakout stars Briton Jack Fenton killed in Greek helicopter accident Emotional Sue Barker gets Centre Court ovation Ukrainian skating sisters back to 'doing what they love ' England v India : Edgbaston officials investigate crowd racism at Test Newspaper headlines : Rwanda plan 'will fail ' and 'SAS train Kyiv forces ' My Name Is Leon : Sir Lenny Henry brings 'moving ' adoption story to screen Big Brother star Glyn Wise plans to be priest Ministers asleep at the wheel over dentist shortages , say Lib Dems Chris Kaba : Met suspends officer who shot dead unarmed man World Cup 2022 : What we learned from a group stage that saw record number of upsets James Webb : Nasa space telescope delivers spectacular pictures Constitution Hill : Cheltenham Champion Hurdle winner 'the horse of a generation ' At least one victim could have survived arena bomb - inquiry Gareth Bale : Wales captain retires from football aged 33 Ukraine war : Silent streets in wiped out Donetsk town World Cup 2022 : Vittorio Pozzo 's legacy and a record that might finally be under threat Train strikes : Workers vote on further six months of walkouts Eidevall '100 % sure ' Arsenal will advance after first-leg draw Ukraine war : Returning to the place my fat ...

# %%
pos_df = pd.DataFrame(columns = ['token', 'post_tag'])
pos_df.head()
# Out:
# Empty DataFrame
# Columns: [token, post_tag]
# Index: []

# %%
for token in spacy_doc:
    pos_df = pd.concat([pos_df, pd.DataFrame.from_records(
    [{'token':token.text, 'pos_tag' : token.pos_}])], ignore_index=True)

# %%
pos_df_counts = pos_df.groupby(['token', 'pos_tag']).size().reset_index(name='counts').sort_values(by='counts',  ascending=False)
pos_df_counts.head(10)
# the raw data as expected has bunch of punctuations and stopwords
# Out:
#      token pos_tag  counts
# 95       :   PUNCT     543
# 8        '   PUNCT     300
# 2897    in     ADP     187
# 4082    to    PART     175
# 3268    of     ADP     172
# 22       -   PUNCT     166
# 4043   the     DET     163
# 1856   and   CCONJ     147
# 15      's    PART     143
# 97       ?   PUNCT     130

# %%
# looking into most common nouns in dataset
nouns = pos_df_counts[pos_df_counts.pos_tag == 'NOUN'][0:10]
nouns
# Out:
#        token pos_tag  counts
# 4267     war    NOUN      35
# 3552  record    NOUN      15
# 3416  police    NOUN      14
# 4316     win    NOUN      14
# 4356    year    NOUN      14
# 3061  living    NOUN      13
# 4009     tax    NOUN      13
# 3368  people    NOUN      12
# 2326     day    NOUN      12
# 2031    boss    NOUN      11

# %%
# looking into most common verb in dataset
verbs = pos_df_counts[pos_df_counts.pos_tag == 'VERB'][0:10]
verbs
# Out:
#        token pos_tag  counts
# 3687    says    VERB      30
# 9          '    VERB      14
# 2670   found    VERB      13
# 4317     win    VERB      12
# 4324    wins    VERB      10
# 2713     get    VERB       9
# 2388    dies    VERB       9
# 3990    take    VERB       8
# 2982  killed    VERB       8
# 3745     set    VERB       8

# %% [markdown]
# ### Clean

# %%
spacy_doc_clean = nlp(' '.join(tokens_clean_list))
spacy_doc_clean
# Out:
# refusework liztrussbriefworldreactsukpoliticalturmoil rationingenergynothingnewoffgridcommunity huntsuperyachtssanctionedrussianoligarchs platinumjubilee70yearsqueen70seconds redbullfoundguiltybreakingformula1sbudgetcap worldtriathlonchampionshipseriesfloraduffybeatsgeorgiataylorbrownwomenstitle terryhallcoventryscooterrideoutpaystributesinger postofficefujitsufaceinquiryhorizonscandal pavementparkingfrightensme ukinterestratesriseaffecthighcouldgo stayedstormhappensnow sixnationsscotlandsbestsince99beatbestirelandever longliztrusssurviveprimeminister platinumjubileebeaconslightacrossglobecelebratequeensreign topstudentloaninterestratecut5england russianssaidtheydtakebabymedicsstory weekpictures1117june2022 xijinpinghongkongtightsecuritycitymarks25yearshandover rescuescarriedsilencelistensoundslife nickpopenewcastlegoalkeeperextendsincrediblecleansheetrecord chinaplansbecomenextbigspacepower barcelonathrashleadersrealmadridfamousclasicowin kuenssbergbudgetcannotmaskbigchangeseconomy nicolabulleysearchknowdisappearance costlivingchristmaslightsdisplayssurviveenergycrisis 100yearoldedinburghmanstillworkingthreedaysweek freya600kgwalruscausesstirnorway offerukhomeukrainianrefugees nicolabulleysearchformerpolicebosssayscriticismunfair bolducdemocratselevatedrepublicanbackfire strikeactioncancelledqueensdeath neighbourhoodleadinggreenenergyrevolution mensu17europeanchampionshipdutch17yearoldisaacbabadiscorespanenkapenalty amtrakderailmentthreekilledmissouritrainhitstruck energypricecaprisingbillsfourdiscountspaymentscouldhelp environmentmushroomboardsfuturesurfing flyingboatstechcleanershipping scottishfootballbanheadingdaymatches chriseubankjrvliamsmithnextboxingunacceptabletaunts towndestroyedmakewaywhitesonlysuburb ukrainewarvillagecelebratesrussianretreat roothitstonenglandtakecommandwestindies heinekenchampionscupleicester166edinburghjasperwiesetrysendstigerslasteight worldcup2022bellinghamgakpofernandezbreakoutstars britonjackfentonkilledgreekhelicopteraccident emotionalsuebarkergetscentrecourtovation ukrainianskatingsistersbackdoinglove englandvindiaedgbastonofficialsinvestigatecrowdracismtest newspaperheadlinesrwandaplanwillfailsastrainkyivforces nameleonsirlennyhenrybringsmovingadoptionstoryscreen bigbrotherstarglynwiseplanspriest ministersasleepwheeldentistshortagessaylibdems chriskabametsuspendsofficershotdeadunarmedman worldcup2022learnedgroupstagesawrecordnumberupsets jameswebbnasaspacetelescopedeliversspectacularpictures constitutionhillcheltenhamchampionhurdlewinnerthehorsegeneration leastonevictimcouldsurvivedarenabombinquiry garethbalewalescaptainretiresfootballaged33 ukrainewarsilentstreetswipeddonetsktown worldcup2022vittoriopozzoslegacyrecordmightfinallythreat trainstrikesworkersvotesixmonthswalkouts eidevall100surearsenaladvancefirstlegdraw ukrainewarreturningplacefatherkilled furniturefirmmadecollapsecustomersdarkrefunds widowuscapitolriotofficerstigmadeath nhsreachesdeallifesavingbreastcancerdrug giantceramicsculpturesandybrownunveiledcornwall ceosecretsonecompanyattractsmen borisbeckertennissuperstarcrashedearth turkishmineexplosionkills25leavesdozenstrapped indianwellsandymurrayemmaraducanujackdraperwinreachthirdround worldathleticschampionshipsgbskeelyhodgkinsonnarrowlymissesgolddramatic800m nhscrisismedicstryingfixhealthservice jetcrashblockflatsrussia princeharrymeghangetmoney chelsea42manutdchelseawinhistoricthirdsuccessivewsltitle toryleadershipratherloserightthingsayssunak omaghpoliceshootingfourmenreleasedjohncaldwellattack northernireland10italysarahmcfaddenscoresfamouswinnerbelfast actressclaradarcystarringplaybraintumour bridgertonsouthasianfacestvmakeshappy princeharryremembersqueenelizabethiisinfectioussmile millionsreceivelatestcostoflivingpayment joebidenheadsmiddleeastamidfalteringussway nhspublicsatisfactionhealthservicedropsrecordlow seenmajorwinterstorms paperslionsbareteethstarmersmigrationpolicy afghanistanpupilsfearspateislamicstateattacks princesswaleskatepaystributequeenelizabethcarol ...

# %%
pos_df_clean = pd.DataFrame(columns = ['token', 'pos_tag'])
pos_df_clean.head()
# Out:
# Empty DataFrame
# Columns: [token, pos_tag]
# Index: []

# %%
for token in spacy_doc_clean:
    pos_df_clean = pd.concat([pos_df_clean, pd.DataFrame.from_records(
    [{'token':token.text, 'pos_tag' : token.pos_}])], ignore_index=True)

# %%
pos_df_counts_clean = pos_df_clean.groupby(['token', 'pos_tag']).size().reset_index(name='counts').sort_values(by='counts',  ascending=False)
pos_df_counts_clean.head()
# Out:
#                                                  token pos_tag  counts
# 895                          ukweatherlongcoldsnaplast     ADJ       2
# 532                 muchcouldmortgagerisetrycalculator   PROPN       2
# 176                               counciltaxmuchrising    VERB       2
# 965  worldathleticschampionshipsgbskeelyhodgkinsonn...   PROPN       1
# 13                 alabamahuntmissingprisoninmateguard    NOUN       1

# %% [markdown]
# ### NER

# %%
ner_df = pd.DataFrame(columns=['token', 'ner_tag'])

for token in spacy_doc.ents:
    if pd.isna(token.label_) is False:
        ner_df = pd.concat([ner_df, pd.DataFrame.from_records(
            [{'token': token.text, 'ner_tag': token.label_}])], ignore_index=True)

# %%
ner_df.head()
# Out:
#          token   ner_tag
# 0    Liz Truss    PERSON
# 1           UK       GPE
# 2    Rationing   PRODUCT
# 3  superyachts  CARDINAL
# 4      Russian      NORP

# %%
 # most common name entity in the dataset
ner_df_counts = ner_df.groupby(['token', 'ner_tag']).size().reset_index(name='counts').sort_values(by='counts', ascending=False)

# %%
ner_df_counts.head(10)
# Out:
#                token      ner_tag  counts
# 965          Ukraine          GPE      47
# 955               UK          GPE      36
# 329          England          GPE      32
# 819          Russian         NORP      20
# 957               US          GPE      19
# 1031  World Cup 2022        EVENT      18
# 1058           first      ORDINAL      13
# 918       The Papers  WORK_OF_ART      13
# 378           France          GPE      12
# 226            China          GPE      11

# %%
# most popular people in dataset
people = ner_df_counts[ner_df_counts.ner_tag == "PERSON"][:10]
people
# Out:
#              token ner_tag  counts
# 257          Covid  PERSON       9
# 757          Putin  PERSON       8
# 760          Queen  PERSON       8
# 563      Liz Truss  PERSON       6
# 169  Boris Johnson  PERSON       6
# 788    Rishi Sunak  PERSON       5
# 325  Emma Raducanu  PERSON       4
# 762           Quiz  PERSON       4
# 581         Macron  PERSON       4
# 515   Jurgen Klopp  PERSON       4
